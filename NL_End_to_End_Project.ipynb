# %% [markdown]
# # Import Required Libraries

# %%
import numpy as np
import pandas as pd
import warnings as wrns
wrns.filterwarnings('ignore')
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import re
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %% [markdown]
# # Data Gathering

# %%
news_df = pd.read_csv("/home/cdot/Documents/Myfirst/fake_news_data/WELFake_Dataset.csv", index_col = 0)
news_df.head()
# Out:
#                                                title
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...  \
# 1                                                NaN
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1
# 3  A dozen politically active pastors came here f...      0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...      1

# %%
df = news_df

# %% [markdown]
# # Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72134 entries, 0 to 72133
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   71576 non-null  object
#  1   text    72095 non-null  object
#  2   label   72134 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.2+ MB

# %%
df["label"].value_counts()
# Out:
# label
# 1    37106
# 0    35028
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (72134, 3)

# %%
df.isna().sum()
# Out:
# title    558
# text      39
# label      0
# dtype: int64

# %%
news_df = df.dropna()

# %%
news_df.isna().sum()
# Out:
# title    0
# text     0
# label    0
# dtype: int64

# %%
news_df.shape
# Out:
# (71537, 3)

# %%
news_df["title"][1:4]
# Out:
# 2    UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3    Bobby Jindal, raised Hindu, uses story of Chri...
# 4    SATAN 2: Russia unvelis an image of its terrif...
# Name: title, dtype: object

# %%
# remove un wanted columns
news_df.drop(["text"], axis = 1, inplace = True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Tokenization

# %%
# sample_data = 'hi my na is anresh Kumar tata naboina'
# split = sample_data.split()

# %%
# sample_data.lower()

# %%
# sw = stopwords.words('english')
# ow = [w for w in split if w not in sw]
# print(ow)

# %%
tokens = word_tokenize("english")
wnl = WordNetLemmatizer()

# %%
for r in news_df['title']:
    print(r[1])
# Out:
# A
# N
# o
# A
# b
# R
# O
# p
# a
# G
# a
# c
# A
# o
# i
# R
# .
# A
# e
# m
# i
# S
# N
# E
# O
# u
# s
# e
# o
# i
# r
# H
# c
# t
# l
# O
# o
# E
# N
#
# r
# R
# r
# e
# a
# l
# T
# n
# m
# e
# n
# .
# r
# e
# n
# B
# S
# e
# .
# o
# P
# E
# i
# a
# G
# r
# i
# h
# I
# o
# e
# o
# d
# e
# h
# o
# h
# A
# o
# N
# N
# n
# I
# .
# H
# b
# N
# h
# a
# n
# r
# T
# O
# T
# i
# o
# O
# E
# n
# o
# O
# A
# h
# O
# A
# o
# A
# o
# O
# O
# e
# u
# N
# o
# A
# T
# n
# e
# h
# r
# I
# i
# u
# o
# a
# E
# A
# a
# -
# o
# e
# h
# e
# R
# i
# a
# o
# H
# W
# o
# F
# e
# o
# h
# i
#
# C
# G
# n
# n
# a
# h
# n
# O
# O
# e
# r
# o
# a
# r
# C
# o
# x
# L
# P
# r
# X
# x
# h
# T
# i
# R
# r
# A
# o
# O
# D
# a
# E
# i
# h
# m
# r
# r
# a
# a
# l
# n
# a
# U
# i
# T
# u
# ‘
# N
# o
# o
# h
# a
# 0
# a
# N
# O
# u
# o
# V
# R
# B
# r
# e
# I
# t
# y
# l
# o
# .
# r
# u
# r
# V
#
# a
# R
# T
# R
# n
# R
# p
# r
# E
# s
# O
# n
# I
# W
# R
# e
# O
# o
# o
# O
# u
# W
# r
# V
# .
# r
# T
# i
# o
# o
# ...
